# %%
import pandas as pd
import numpy as np

# %%
Iris = pd.read_csv("/kaggle/input/iris/Iris.csv")

# %%
print(Iris)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df = pd.DataFrame(Iris, columns=("Id", "SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm", "Species"))

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
Iris = pd.get_dummies(Iris, columns=['Species'])

# %%
print(Iris.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species_Iris-setosa', 'Species_Iris-versicolor',
#        'Species_Iris-virginica'],
#       dtype='object')

# %%
df_scaled = df.drop(columns=['Species'])

# %%
scaler = StandardScaler() #데이터 표준화 
df_scaled = scaler.fit_transform(df_scaled) # 표준화된 데이터는 numpy 배열로 반환됨

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2, include_bias=False)
poly.fit_transform(df_scaled)
# Out:
# array([[-1.72054204, -0.90068117,  1.03205722, ...,  1.79901166,
#          1.76105945,  1.72390789],
#        [-1.69744751, -1.14301691, -0.1249576 , ...,  1.79901166,
#          1.76105945,  1.72390789],
#        [-1.67435299, -1.38535265,  0.33784833, ...,  1.95479017,
#          1.8357228 ,  1.72390789],
#        ...,
#        [ 1.67435299,  0.79566902, -0.1249576 , ...,  0.67178407,
#          0.86350436,  1.10993965],
#        [ 1.69744751,  0.4321654 ,  0.80065426, ...,  0.87115297,
#          1.35145773,  2.09657554],
#        [ 1.72054204,  0.06866179, -0.1249576 , ...,  0.58180075,
#          0.60302996,  0.6250338 ]])

# %%
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Iris = Iris.drop(columns=['Id'])

# %%
#  # 인코딩 후 'Species'는 제외
# x = Iris.drop(columns=['Species_Iris-setosa', 'Species_Iris-versicolor', 'Species_Iris-virginica']) 
# # 원-핫 인코딩된 종 정보를 y로 설정
# y = Iris[['Species_Iris-setosa', 'Species_Iris-versicolor', 'Species_Iris-virginica']]

# %%
x = Iris[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
       'Species_Iris-setosa', 'Species_Iris-versicolor',
       'Species_Iris-virginica']]

# %%
#  # 인코딩 후 'Species'는 제외
# x1 = Iris.drop(columns=['Species_Iris-setosa', 'Species_Iris-versicolor', 'Species_Iris-virginica']) 
# # 원-핫 인코딩된 종 정보를 y로 설정
# y1 = Iris[['Species_Iris-versicolor']]

# %%
#  # 인코딩 후 'Species'는 제외
# x2 = Iris.drop(columns=['Species_Iris-setosa', 'Species_Iris-versicolor', 'Species_Iris-virginica']) 
# # 원-핫 인코딩된 종 정보를 y로 설정
# y2 = Iris[['Species_Iris-virginica']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
sns.pairplot(x_train)  # train 데이터에서 4개의 특성에 대해 산점도 쌍을 그립니다.
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.pairplot(y_train)  # train 데이터에서 4개의 특성에 대해 산점도 쌍을 그립니다.
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_stats/counting.py:137: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   bin_edges = np.histogram_bin_edges(vals, bins, binrange, weight)
# /opt/conda/lib/python3.10/site-packages/seaborn/_stats/counting.py:176: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   hist, edges = np.histogram(vals, **bin_kws, weights=weights, density=density)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=200)  # max_iter을 늘려서 수렴 문제 해결
model.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[233], line 3
#       1 from sklearn.linear_model import LogisticRegression
#       2 model = LogisticRegression(max_iter=200)  # max_iter을 늘려서 수렴 문제 해결
# ----> 3 model.fit(x_train, y_train)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1196, in LogisticRegression.fit(self, X, y, sample_weight)
#    1193 else:
#    1194     _dtype = [np.float64, np.float32]
# -> 1196 X, y = self._validate_data(
#    1197     X,
#    1198     y,
#    1199     accept_sparse="csr",
#    1200     dtype=_dtype,
#    1201     order="C",
#    1202     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1203 )
#    1204 check_classification_targets(y)
#    1205 self.classes_ = np.unique(y)
#
# ...
