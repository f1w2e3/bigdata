# %%
import pandas as pd

# %%
import numpy as np #파이썬의 배열 라이브러리

# %%
df1 = pd.DataFrame([[35.0, 700.0], [11.8, 9.8]],
                   columns=["length", "weight"],
                   index=["도미", "빙어"])

# %%
df1
# Out:
#     length  weight
# 도미    35.0   700.0
# 빙어    11.8     9.8

# %%
length = [[25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0, 31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0, 35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0], [9.8, 10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0]]
weight = [[242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0, 500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0, 700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0], [6.7, 7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9]]
name = ["도미", "빙어"]

data = list(zip(length, weight))

df2 = pd.DataFrame(data, columns=["length","weight"], index=name)

# %%
df2
# Out:
#                                                length  \
# 도미  [25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30....
# 빙어  [9.8, 10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8...
#
#                                                weight
# 도미  [242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500...
# 빙어  [6.7, 7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8,...

# %%
df3 = pd.DataFrame([[[25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0, 31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0, 35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0], [242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0, 500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0, 700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0]], [[9.8, 10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0], [6.7, 7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9]]],
                   columns=["length", "weight"],
                   index=["도미", "빙어"])

# %%
df3
# Out:
#                                                length  \
# 도미  [25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30....
# 빙어  [9.8, 10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8...
#
#                                                weight
# 도미  [242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500...
# 빙어  [6.7, 7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8,...

# %%
사과 = [3, 10, 6]
자두 = [2, 0, 5]
포도 = [5, 2, 3]
name = ["이성계", "김유신", "이순신"]

data = list(zip(사과, 자두, 포도))
df4 = pd.DataFrame(data, columns=("사과", "자두", "포도"), index=name)

# %%
df4
# Out:
#      사과  자두  포도
# 이성계   3   2   5
# 김유신  10   0   2
# 이순신   6   5   3

# %%
bream_length = [25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0, 31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0, 35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0]
bream_weight = [242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0, 500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0, 700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0]

smelt_length = [9.8, 10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0]
smelt_weight = [6.7, 7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9]

# %%
fish_length = bream_length + smelt_length
fish_weight = bream_weight + smelt_weight

fish_data = [[l, w] for l, w in zip(fish_length, fish_weight)]

# %%
#도미1,도미2, ... 도미35
fishname1 = ["도미" + str(i+1) for i in range(35)]
#빙어1,빙어2, ... 빙어14
fishname2 = ["빙어" + str(i+1) for i in range(14)]
#모든 물고기 이름
fishname=fishname1+fishname2  #[도미1,도미2, .... , 도미35, 빙어1, 빙어2, ...빙어14]

print(fishname1)
print(fishname2)
print(fishname)
# Out:
# ['도미1', '도미2', '도미3', '도미4', '도미5', '도미6', '도미7', '도미8', '도미9', '도미10', '도미11', '도미12', '도미13', '도미14', '도미15', '도미16', '도미17', '도미18', '도미19', '도미20', '도미21', '도미22', '도미23', '도미24', '도미25', '도미26', '도미27', '도미28', '도미29', '도미30', '도미31', '도미32', '도미33', '도미34', '도미35']
# ['빙어1', '빙어2', '빙어3', '빙어4', '빙어5', '빙어6', '빙어7', '빙어8', '빙어9', '빙어10', '빙어11', '빙어12', '빙어13', '빙어14']
# ['도미1', '도미2', '도미3', '도미4', '도미5', '도미6', '도미7', '도미8', '도미9', '도미10', '도미11', '도미12', '도미13', '도미14', '도미15', '도미16', '도미17', '도미18', '도미19', '도미20', '도미21', '도미22', '도미23', '도미24', '도미25', '도미26', '도미27', '도미28', '도미29', '도미30', '도미31', '도미32', '도미33', '도미34', '도미35', '빙어1', '빙어2', '빙어3', '빙어4', '빙어5', '빙어6', '빙어7', '빙어8', '빙어9', '빙어10', '빙어11', '빙어12', '빙어13', '빙어14']

# %%
fish_target = [1]*35 + [0]*14

# %%
df5=pd.DataFrame(
  fish_data,
  columns=["길이","무게"],
  index=fishname
)

df5
# Out:
#         길이      무게
# 도미1   25.4   242.0
# 도미2   26.3   290.0
# 도미3   26.5   340.0
# 도미4   29.0   363.0
# 도미5   29.0   430.0
# 도미6   29.7   450.0
# 도미7   29.7   500.0
# 도미8   30.0   390.0
# 도미9   30.0   450.0
# 도미10  30.7   500.0
# 도미11  31.0   475.0
# 도미12  31.0   500.0
# 도미13  31.5   500.0
# 도미14  32.0   340.0
# 도미15  32.0   600.0
# 도미16  32.0   600.0
# 도미17  33.0   700.0
# 도미18  33.0   700.0
# 도미19  33.5   610.0
# 도미20  33.5   650.0
# 도미21  34.0   575.0
# 도미22  34.0   685.0
# 도미23  34.5   620.0
# 도미24  35.0   680.0
# 도미25  35.0   700.0
# 도미26  35.0   725.0
# 도미27  35.0   720.0
# 도미28  36.0   714.0
# 도미29  36.0   850.0
# 도미30  37.0  1000.0
# 도미31  38.5   920.0
# 도미32  38.5   955.0
# 도미33  39.5   925.0
# 도미34  41.0   975.0
# 도미35  41.0   950.0
# 빙어1    9.8     6.7
# 빙어2   10.5     7.5
# 빙어3   10.6     7.0
# 빙어4   11.0     9.7
# 빙어5   11.2     9.8
# 빙어6   11.3     8.7
# 빙어7   11.8    10.0
# 빙어8   11.8     9.9
# 빙어9   12.0     9.8
# 빙어10  12.2    12.2
# 빙어11  12.4    13.4
# ...

# %%
train_input = fish_data[:35]
train_target = fish_target[:35]

test_input = fish_data[35:]
test_target = fish_target[35:]

# %%
print(len(fish_data))  # 출력: 49
print(len(fishname))   # 출력: 49
# Out:
# 49
# 49

# %%
from sklearn.neighbors import KNeighborsClassifier
kn = KNeighborsClassifier()
kn = kn.fit(train_input, train_target)

kn.score(test_input, test_target)
# Out:
# 0.0

# %%
input_arr = np.array(fish_data)
target_arr = np.array(fish_target)

print(input_arr)
# Out:
# [[  25.4  242. ]
#  [  26.3  290. ]
#  [  26.5  340. ]
#  [  29.   363. ]
#  [  29.   430. ]
#  [  29.7  450. ]
#  [  29.7  500. ]
#  [  30.   390. ]
#  [  30.   450. ]
#  [  30.7  500. ]
#  [  31.   475. ]
#  [  31.   500. ]
#  [  31.5  500. ]
#  [  32.   340. ]
#  [  32.   600. ]
#  [  32.   600. ]
#  [  33.   700. ]
#  [  33.   700. ]
#  [  33.5  610. ]
#  [  33.5  650. ]
#  [  34.   575. ]
#  [  34.   685. ]
#  [  34.5  620. ]
#  [  35.   680. ]
#  [  35.   700. ]
#  [  35.   725. ]
#  [  35.   720. ]
#  [  36.   714. ]
#  [  36.   850. ]
#  [  37.  1000. ]
#  [  38.5  920. ]
#  [  38.5  955. ]
#  [  39.5  925. ]
#  [  41.   975. ]
#  [  41.   950. ]
#  [   9.8    6.7]
#  [  10.5    7.5]
#  [  10.6    7. ]
#  [  11.     9.7]
#  [  11.2    9.8]
#  [  11.3    8.7]
#  [  11.8   10. ]
#  [  11.8    9.9]
#  [  12.     9.8]
#  [  12.2   12.2]
#  [  12.4   13.4]
#  [  13.    12.2]
#  [  14.3   19.7]
#  [  15.    19.9]]

# %%
index = np.arange(49)
np.random.shuffle(index) #np.random.seed? 재현성을 위해서 / 일반적으로는 seed를 지정할 필요X

# %%
train_input = input_arr[index[:35]]
train_target = target_arr[index[:35]]

test_input = input_arr[index[35:]]
test_target = target_arr[index[35:]]

# %%
#배열 슬라이싱
a = np.array([5, 6, 7, 8])
a[[1,3]] #a배열에서 0,1,2,3번째 중에 1번, 3번을 불러오는 방법
# Out:
# array([6, 8])

# %%
import matplotlib.pyplot as plt
plt.scatter(train_input[:, 0], train_input[:, 1]) #[:, 0]과 [:, 1]은 0번째 컬럼(열)의 모든 행과 1번째 컬럼(열)의 모든 행을 지정하는 내용이다
plt.scatter(test_input[:, 0], test_input[:, 1])
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %%
kn = kn.fit(train_input, train_target)
kn.score(test_input, test_target)
# Out:
# 1.0

# %%
b=[1,2,3]
b[0]
# Out:
# 1

# %%
fish_data[0:14]
# Out:
# [[25.4, 242.0],
#  [26.3, 290.0],
#  [26.5, 340.0],
#  [29.0, 363.0],
#  [29.0, 430.0],
#  [29.7, 450.0],
#  [29.7, 500.0],
#  [30.0, 390.0],
#  [30.0, 450.0],
#  [30.7, 500.0],
#  [31.0, 475.0],
#  [31.0, 500.0],
#  [31.5, 500.0],
#  [32.0, 340.0]]

# %%
fish_data = np.column_stack((fish_length, fish_weight)) #column_stack =zip함수를 대체하는 좋은 방식

# %%
fish_target = np.concatenate((np.ones(35), np.zeros(14)))

# %%
from sklearn.model_selection import train_test_split  #split함수는 데이터 값을 섞어서 나눠주는 역활(%비율로 나눠줌)

train_input, test_input, train_target, test_target = train_test_split(fish_data, fish_target, stratify=fish_target, random_state=42) #random_state는 함수생성의 난수생성 시드를 고정시키는 역활 / stratify는 split의 나눠주는 비율을 자동으로 최적화시켜줌

# %%
from sklearn.neighbors import KNeighborsClassifier
kn = KNeighborsClassifier()
kn = kn.fit(train_input, train_target)

kn.score(test_input, test_target)
# Out:
# 1.0

# %%
print(kn.predict([[25, 150]]))
# Out:
# [0.]

# %%
distances, indexes = kn.kneighbors([[25, 150]])

plt.scatter(train_input[:,0], train_input[:,1])
plt.scatter(25, 150, marker='^')
plt.scatter(train_input[indexes,0], train_input[indexes,1], marker='D')

plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %%
plt.scatter(train_input[:,0], train_input[:,1])
plt.scatter(25, 150, marker='^')
plt.scatter(train_input[indexes,0], train_input[indexes,1], marker='D')

plt.xlim((0, 1000))
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %%
mean = np.mean(train_input, axis=0)
std = np.std(train_input, axis=0)

print(mean, std)
# Out:
# [ 27.29722222 454.09722222] [  9.98244253 323.29893931]

# %%
train_scaled = (train_input - mean) / std

# %%
new = ([25, 150] - mean) / std

plt.scatter(train_scaled[:,0], train_scaled[:,1])
plt.scatter(new[0], new[1], marker='^')
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %%
kn.fit(train_scaled, train_target)

test_scaled = (test_input - mean) / std
kn.score(test_scaled, test_target)
# Out:
# 1.0

# %%
print(kn.predict([new]))
# Out:
# [1.]

# %%
distances, indexes = kn.kneighbors([new])

plt.scatter(train_scaled[:,0], train_scaled[:,1])
plt.scatter(new[0], new[1], marker='^')
plt.scatter(train_scaled[indexes,0], train_scaled[indexes,1], marker='D')
plt.xlabel('length')
plt.ylabel('weight')
plt.show()
